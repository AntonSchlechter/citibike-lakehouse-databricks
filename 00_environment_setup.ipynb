# %%
# %sql
create catalog if not exists citibike_lakehouse;

# %%
# %sql
create schema if not exists citibike_lakehouse.bronze;

create schema if not exists citibike_lakehouse.silver;

create schema if not exists citibike_lakehouse.gold;

create schema if not exists citibike_lakehouse.ml;
